# %%
import sqlalchemy

# %%
import pymysql

# %%
sqlalchemy.__version__
# Out:
# '1.3.18'

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:rockstar2@localhost/inp')

# %%
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
from sqlalchemy import Column, Integer, String, Float, DateTime

# %%
class telescopes(Base):
    __tablename__ = 'telescopes'
    
    ID = Column(String(45), primary_key=True)
    name = Column(String(45))
    latitude = Column(Float)
    longitude = Column(Float)

    def __repr__(self):
        return "<telescopes(name='%s', latitude='%f')>" % (self.name, self.latitude)

# %%
telescopes.__table__
# Out:
# Table('telescopes', MetaData(bind=None), Column('ID', String(length=45), table=<telescopes>, primary_key=True, nullable=False), Column('name', String(length=45), table=<telescopes>), Column('latitude', Float(), table=<telescopes>), Column('longitude', Float(), table=<telescopes>), schema=None)

# %%
Base.metadata.create_all(engine)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     324         else:
# --> 325             self.connect()
#     326
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     598             self._get_server_information()
# --> 599             self._request_authentication()
#     600
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\connections.py in _request_authentication(self)
#     881             if self._auth_plugin_name == "caching_sha2_password":
# --> 882                 auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     883             elif self._auth_plugin_name == "sha256_password":
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\_auth.py in caching_sha2_password_auth(conn, pkt)
#     237             print("caching sha2: succeeded by fast path.")
# --> 238         pkt = conn._read_packet()
#     239         pkt.check_error()  # pkt must be OK packet
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1049, "Unknown database 'inp'")
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-18-492787049b38> in <module>
# ----> 1 Base.metadata.create_all(engine)
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\sql\schema.py in create_all(self, bind, tables, checkfirst)
#    4545             bind = _bind_or_error(self)
#    4546         bind._run_visitor(
# -> 4547             ddl.SchemaGenerator, self, checkfirst=checkfirst, tables=tables
#    4548         )
#    4549
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\engine\base.py in _run_visitor(self, visitorcallable, element, connection, **kwargs)
#    2095         self, visitorcallable, element, connection=None, **kwargs
#    2096     ):
# -> 2097         with self._optional_conn_ctx_manager(connection) as conn:
#    2098             conn._run_visitor(visitorcallable, element, **kwargs)
#    2099
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2087     def _optional_conn_ctx_manager(self, connection=None):
#    2088         if connection is None:
# -> 2089             with self._contextual_connect() as conn:
#    2090                 yield conn
#    2091         else:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2303         return self._connection_cls(
#    2304             self,
# -> 2305             self._wrap_pool_connect(self.pool.connect, None),
#    2306             close_with_result=close_with_result,
#    2307             **kwargs
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2341             if connection is None:
#    2342                 Connection._handle_dbapi_exception_noconnection(
# -> 2343                     e, dialect, self
#    2344                 )
#    2345             else:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1583         elif should_wrap:
#    1584             util.raise_(
# -> 1585                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1586             )
#    1587         else:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         dialect = self.dialect
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     323             self._sock = None
#     324         else:
# --> 325             self.connect()
#     326
#     327     def _create_ssl_ctx(self, sslp):
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     597
#     598             self._get_server_information()
# --> 599             self._request_authentication()
#     600
#     601             if self.sql_mode is not None:
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\connections.py in _request_authentication(self)
#     880             # https://dev.mysql.com/doc/internals/en/successful-authentication.html
#     881             if self._auth_plugin_name == "caching_sha2_password":
# --> 882                 auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     883             elif self._auth_plugin_name == "sha256_password":
#     884                 auth_packet = _auth.sha256_password_auth(self, auth_packet)
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\_auth.py in caching_sha2_password_auth(conn, pkt)
#     236         if DEBUG:
#     237             print("caching sha2: succeeded by fast path.")
# --> 238         pkt = conn._read_packet()
#     239         pkt.check_error()  # pkt must be OK packet
#     240         return pkt
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# c:\Users\nikita.agarwal\OneDrive\Attachments\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (pymysql.err.InternalError) (1049, "Unknown database 'inp'")
# (Background on this error at: http://sqlalche.me/e/13/2j85)
